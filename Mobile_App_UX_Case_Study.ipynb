# %%
from IPython.display import display, HTML

html_code = """
<style>
body { font-family: Arial; }
.container {
    width: 360px;
    border: 2px solid #ccc;
    border-radius: 20px;
    padding: 15px;
}
.header {
    text-align: center;
    font-weight: bold;
    font-size: 20px;
    margin-bottom: 10px;
}
.screen {
    border: 1px solid #ddd;
    border-radius: 15px;
    padding: 10px;
    margin-bottom: 15px;
}
.btn {
    background: #4CAF50;
    color: white;
    padding: 8px;
    text-align: center;
    border-radius: 8px;
    margin-top: 5px;
}
.input {
    border: 1px solid #ccc;
    padding: 6px;
    border-radius: 5px;
    margin-bottom: 6px;
}
</style>

<div class="container">
  <div class="header">📱 Task Manager App UX</div>

  <div class="screen">
    <b>🔐 Login Screen</b><br><br>
    <div class="input">Email</div>
    <div class="input">Password</div>
    <div class="btn">Login</div>
  </div>

  <div class="screen">
    <b>🏠 Home Screen</b><br>
    ✔ View Tasks<br>
    ✔ Add Task<br>
    ✔ Track Progress
  </div>

  <div class="screen">
    <b>➕ Add Task</b><br><br>
    <div class="input">Task Name</div>
    <div class="input">Due Date</div>
    <div class="input">Priority</div>
    <div class="btn">Save Task</div>
  </div>

  <div class="screen">
    <b>📋 Task List</b><br>
    ☐ Complete UX assignment<br>
    ☐ Prepare report<br>
    ☐ Revise Python
  </div>

  <div class="screen">
    <b>👤 Profile</b><br>
    Name: Student<br>
    Role: Intern<br>
    <div class="btn">Logout</div>
  </div>
</div>
"""

display(HTML(html_code))
# Out:
# <style>
# body { font-family: Arial; }
# .container {
#     width: 360px;
#     border: 2px solid #ccc;
#     border-radius: 20px;
#     padding: 15px;
# }
# .header {
#     text-align: center;
#     font-weight: bold;
#     font-size: 20px;
#     margin-bottom: 10px;
# }
# .screen {
#     border: 1px solid #ddd;
#     border-radius: 15px;
#     padding: 10px;
#     margin-bottom: 15px;
# }
# .btn {
#     background: #4CAF50;
#     color: white;
#     padding: 8px;
#     text-align: center;
#     border-radius: 8px;
#     margin-top: 5px;
# }
# .input {
#     border: 1px solid #ccc;
#     padding: 6px;
#     border-radius: 5px;
#     margin-bottom: 6px;
# }
# </style>
#
# <div class="container">
#   <div class="header">📱 Task Manager App UX</div>
#
#   <div class="screen">
#     <b>🔐 Login Screen</b><br><br>
#     <div class="input">Email</div>
#     <div class="input">Password</div>
#     <div class="btn">Login</div>
#   </div>
#
#   <div class="screen">
# ...
